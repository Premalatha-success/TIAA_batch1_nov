# %% [markdown]
# https://www.linkedin.com/in/latha-t-k-b21018128/

# %% [markdown]
# https://www.youtube.com/@datasciencemonster3703

# %% [markdown]
# ![image.png](attachment:16805439-8780-4bac-bd1a-5eb6a161355e.png)

# %% [markdown]
# ### My First Program

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ### Print ur name

# %%
print("Latha")
# Out:
# Latha

# %%
Print("Python")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("Python")
#
# NameError: name 'Print' is not defined

# %% [markdown]
# #### Python is case sensitive

# %%
x=10
x
# Out:
# 10

# %%
x=10

# %%
y=-17

# %%
y
# Out:
# -17

# %%
x
# Out:
# 10

# %%
course="Python"
course
# Out:
# 'Python'

# %%
name="Latha"
designation="Corporate Trainer"
experience=17
print(name)
print(designation)
print(experience)
# Out:
# Latha
# Corporate Trainer
# 17

# %% [markdown]
# ### Rules for naming the variables

# %%
first name="Prema"
first name
# Out:
#   Cell In[18], line 1
#     first name="Prema"
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Spacing is not allowed

# %%
first_name="Prema"
first_name
# Out:
# 'Prema'

# %%
first+name="Prema"
first+name
# Out:
#   Cell In[21], line 1
#     first+name="Prema"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# ##### The only allowed special char is underscore

# %%
name="latha"
Name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 name="latha"
# ----> 2 Name
#
# NameError: name 'Name' is not defined

# %%
100names="Prema","Latha"
100names
# Out:
#   Cell In[24], line 1
#     100names="Prema","Latha"
#       ^
# SyntaxError: invalid decimal literal

# %%
n2ames="prem"
n2ames
# Out:
# 'prem'

# %% [markdown]
# ##### Variable names should not start with a number
# ##### Starts with A-Z,a-z,or _
# ##### Space is not allowed
# ##### The only allowed spl char is _

# %%
tom_age=alex_age=gary_age=27
print(tom_age)
print(alex_age)
# Out:
# 27
# 27

# %%
print("Alex_age=",alex_age)
print("Tom's_age=",tom_age)
# Out:
# Alex_age= 27
# Tom's_age= 27

# %% [markdown]
# ### Data Types

# %%
course="Python"
type(course)
# Out:
# str

# %%
x=10
type(x)
# Out:
# int

# %%
x=10.8
type(x)
# Out:
# float

# %%
y=True
type(y)
# Out:
# bool

# %%
y=true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 y=true
#
# NameError: name 'true' is not defined

# %%
y="true"
type(y)
# Out:
# str

# %% [markdown]
# #### int->integer(no decimal point)
# #### float->number with decimal point
# #### str->string(text data)/object
# #### bool->boolean->True or False

# %%
4+10
# Out:
# 14

# %%
14/2
# Out:
# 7.0

# %% [markdown]
# ##### Implicit Coversion-> Datatype conversion is done without Programmer's intervention

# %%
price=500
tax="25"
total_price=price+tax
total_price
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 price=500
#       2 tax="25"
# ----> 3 total_price=price+tax
#       4 total_price
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
price=500.00
tax="25"
total_price=price+tax
total_price
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 price=500.00
#       2 tax="25"
# ----> 3 total_price=price+tax
#       4 total_price
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %% [markdown]
# #### Explicit Conversion->Programmers have to change the data type explicitly

# %%
price=500.00
tax="25"
total_price=price+float(tax)
total_price
# Out:
# 525.0

# %%
price=500.00
tax="25"
total_price=price+int(tax)
total_price
# Out:
# 525.0

# %%
unit_price=25
float(unit_price)
# Out:
# 25.0

# %%
str(unit_price)
# Out:
# '25'

# %%
bool(unit_price)
# Out:
# True

# %%
price=0
bool(price)
# Out:
# False

# %%
z="1"
float(z)
# Out:
# 1.0

# %%
z="python"
float(z)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 2
#       1 z="python"
# ----> 2 float(z)
#
# ValueError: could not convert string to float: 'python'

# %%
bool(z)
# Out:
# True

# %%
x=False
int(x)
# Out:
# 0

# %%
str(x)
# Out:
# 'False'

# %%
print("Python is fun')
# Out:
#   Cell In[54], line 1
#     print("Python is fun')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("Python "+"is fun")
# Out:
# Python is fun

# %%
print("Sam's age is" +25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print("Sam's age is" +25)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("Sam's age is " +str(25))
# Out:
# Sam's age is 25

# %% [markdown]
# ### Operators

# %% [markdown]
# ##### Arithmetic Operators

# %%
income=1000000 
incentives=10000
total_income=income + incentives
total_income
# Out:
# 1010000

# %%
first_name="Prema"
last_name="Latha"
full_name=first_name+last_name
full_name
# Out:
# 'PremaLatha'

# %%
first_name="Prema"
last_name="Latha"
full_name=first_name-last_name
full_name
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 3
#       1 first_name="Prema"
#       2 last_name="Latha"
# ----> 3 full_name=first_name-last_name
#       4 full_name
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
value="India "
count=25
result=value*count
result
# Out:
# 'India India India India India India India India India India India India India India India India India India India India India India India India India '

# %%
value="India "
count=25
result=value/count
result
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 value="India "
#       2 count=25
# ----> 3 result=value/count
#       4 result
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
5+2
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5**2
# Out:
# 25

# %%
6**4
# Out:
# 1296

# %%
#### Modulus(%)
#### a%b-> if a >b -> Remainder else a

# %%
10%2
# Out:
# 0

# %%
2%10
# Out:
# 2

# %%
10%3
# Out:
# 1

# %%
3%10
# Out:
# 3

# %%
10%4
# Out:
# 2

# %%
10%5
# Out:
# 0

# %% [markdown]
# ### Floor Division // -> a//b(if a>b,it returns quotient else 0)

# %%
10//3
# Out:
# 3

# %%
3//10
# Out:
# 0

# %%
10//4
# Out:
# 2

# %%
10//5
# Out:
# 2

# %%
10//6
# Out:
# 1

# %%
5//10
# Out:
# 0

# %% [markdown]
# ### Relational Operators

# %%
tom_age=25
kenny_age=30

# %%
tom_age<kenny_age
# Out:
# True

# %%
tom_age>kenny_age
# Out:
# False

# %%
tom_age<=kenny_age
# Out:
# True

# %%
tom_age==kenny_age
# Out:
# False

# %%
tom_age!=kenny_age
# Out:
# True

# %% [markdown]
# #### Logical Operators

# %%
is_student=True
in_college=True
in_school=False
is_male=False

# %%
is_student and in_school
# Out:
# False

# %%
is_student or in_school
# Out:
# True

# %%
not(is_student)
# Out:
# False

# %%
not(is_student) or not(in_school)
# Out:
# True

# %%
### weekend plan decision
is_sunny=False
has_free_time=True
is_tired=False
go_out=not(is_sunny) and has_free_time and not(is_tired)

# %%
go_out
# Out:
# True

# %% [markdown]
# ### Github link:https://github.com/Premalatha-success/TIAA_batch1_nov

# %% [markdown]
# #### Membership operators

# %%
vowels="aeiou"
"u" in vowels
# Out:
# True

# %%
vowels="aeiou"
print("u" in vowels)
# Out:
# True

# %%
print("s" in vowels)
# Out:
# False

# %%
print("u" not in vowels)
# Out:
# False

# %%
print("s" not in vowels)
# Out:
# True

# %% [markdown]
# #### Strings

# %%
str1="Hello Python"
str1
# Out:
# 'Hello Python'

# %%
str1='Hello Python"
str1
# Out:
#   Cell In[107], line 1
#     str1='Hello Python"
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
str1="""Hello Python"""
str1
# Out:
# 'Hello Python'

# %%
str1="""Hello 
        Python"""
str1
# Out:
# 'Hello \n        Python'

# %%
str1="Hello Python"
str1
# Out:
# 'Hello Python'

# %%
len(str1)
# Out:
# 12

# %% [markdown]
# ##### indexing

# %%
str1[0]
# Out:
# 'H'

# %%
str1[5]
# Out:
# ' '

# %%
str1[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 str1[100]
#
# IndexError: string index out of range

# %%
str1[12]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 str1[12]
#
# IndexError: string index out of range

# %%
str1[11]
# Out:
# 'n'

# %%
str1[6]
# Out:
# 'P'

# %%
str1[-6]
# Out:
# 'P'

# %%
str1[len(str1)-1]
# Out:
# 'n'

# %% [markdown]
# #### slicing

# %%
str1[0:5]
# Out:
# 'Hello'

# %%
str1[6:12]
# Out:
# 'Python'

# %%
str1[8:12]
# Out:
# 'thon'

# %%
str1[-4:]
# Out:
# 'thon'

# %%
str1[-11:]
# Out:
# 'ello Python'

# %%
str1[0:4]
# Out:
# 'Hell'

# %%
str1[-12:-8]
# Out:
# 'Hell'

# %%
str1[:4]
# Out:
# 'Hell'

# %%
str1[0:5]="hallo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 str1[0:5]="hallo"
#
# TypeError: 'str' object does not support item assignment

# %%
del str1

# %%
str1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[134], line 1
# ----> 1 str1
#
# NameError: name 'str1' is not defined

# %%
### string concatenation
s1="hello"
s2="python"
s3=s1+s2
s3
# Out:
# 'hellopython'

# %%
s3=s1+" "+s2

# %%
s3
# Out:
# 'hello python'

# %%
### Iterating through a string
mystr="Hello have a good day"
mystr
# Out:
# 'Hello have a good day'

# %%
for i in mystr:
    print(i)
# Out:
# H
# e
# l
# l
# o
#
# h
# a
# v
# e
#
# a
#
# g
# o
# o
# d
#
# d
# a
# y

# %%
mystr.lower()
# Out:
# 'hello have a good day'

# %%
mystr.upper()
# Out:
# 'HELLO HAVE A GOOD DAY'

# %%
mystr.title()
# Out:
# 'Hello Have A Good Day'

# %%
mystr
# Out:
# 'Hello have a good day'

# %%
mystr.replace("day","night")
# Out:
# 'Hello have a good night'

# %%
mystr
# Out:
# 'Hello have a good day'

# %%
"day" in mystr
# Out:
# True
